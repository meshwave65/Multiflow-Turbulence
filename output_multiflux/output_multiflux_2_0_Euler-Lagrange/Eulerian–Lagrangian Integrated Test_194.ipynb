# %%
# ============================================================
# Multiflux Theory v2.0 — Variational Validation
# Resolution: N = 194³
# Author: D. D. Sobral
# ============================================================

import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import pandas as pd

# -----------------------
# 1) Parâmetros globais
# -----------------------
N = 1024
K_CLUSTERS = 12
SEED = 42

np.random.seed(SEED)

OUTDIR = f"results/multiflux_v2_N{N}"
os.makedirs(OUTDIR, exist_ok=True)

print(f"Running Multiflux v2.0 | N = {N}³")

# -----------------------
# 2) Campo de velocidade (HIT sintético normalizado)
# -----------------------
u = np.random.randn(N, N, N)
v = np.random.randn(N, N, N)
w = np.random.randn(N, N, N)

# Normalização forte (evita overflow ao escalar)
norm = np.sqrt(np.mean(u**2 + v**2 + w**2))
u /= norm
v /= norm
w /= norm

print("Velocity field generated and normalized.")

# -----------------------
# 3) Gradi
