# %%
# Out:
# Análise Rápida:
# N_eff = 12
# Correlação Dissipation vs Volume: -0.7638925611689907
# Correlação Action vs Volume: 0.7638731880677117
# Dominantes (volume >10%) minimizam dissipation: 0.001368909706
# Pequenos (volume <5%) maximizam dissipation: 0.00401005605
